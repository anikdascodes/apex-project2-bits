# %% [markdown]
# # Advanced Apex Project-2 (M.Sc. DS & AI)
#
# Students are strongly encouraged to include markdown explanations, observations, and interpretations between code cells to improve readability, reproducibility, and AI-assisted evaluation quality.
#
# This notebook supports:
# - Classification
# - Regression
# - Clustering
# - ANN Projects
#
# Complete only the sections relevant to your project.
#
# # Week-2 Project Outline

# %% [markdown]
# ## Problem Statement & Business Goal

# %% [markdown]
# ## Dataset Details

# %%
import pandas as pd
df = pd.read_csv('your_dataset.csv')
df.head()

# %% [markdown]
# ## Initial Dataset Inspection

# %%
print(df.shape)
print(df.dtypes)
print(df.isnull().sum())

# %% [markdown]
# ## Initial Observations

# %% [markdown]
# ## Proposed Workflow

# %% [markdown]
# ## Proposed Modelling Plan
# - Baseline model:
# - Comparison models:
# - Evaluation metrics:
# - Tuning plan:

# %% [markdown]
# ## References
